# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
# Make global settings for the figures.
mpl.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']
plt.rcParams["mathtext.default"] = 'regular'
mpl.rcParams['pdf.fonttype'] = 42
# This is for using seaborn
sns.set_theme(style="white")
sns.set_style('ticks')

# declare paths to save to and extract data exce sheet files.
save_path ='../plots/'
data_path = "../SSB_literature_Hg_data.xlsx"
font_size = 12

# %%
# import data into a pandas dataframe.
cha = pd.read_excel(data_path, sheet_name="Chaohu")
cha.head(3)
# Out:
#         Age  Sample  Lithology  depth       TOC   Hg  Hg_TOC    d202Hg  \
# 0  Smithian  CH26-1  limestone  30.65  0.028307  5.8     NaN -1.196602
# 1  Smithian  CH26-4  limestone  31.65  0.031078  4.4     NaN       NaN
# 2  Smithian  CH26-7  limestone  32.65  0.019441  3.8     NaN       NaN
#
#    d202_2se    D199Hg  D199_2se    D200Hg  D200_2se    D201Hg  D201_2se  \
# 0      0.03  0.163477      0.04  0.011747      0.04  0.034643      0.01
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#             Locality            Author
# 0  West Pingdingshan  Wang et al. 2019
# 1  West Pingdingshan               NaN
# 2  West Pingdingshan               NaN

# %%
depth = cha.depth
D199 = cha.D199Hg
Hg = cha.Hg
Hg_TOC=cha.Hg_TOC
err199 = cha.D199_2se

# %%
fig, axes = plt.subplots(figsize=(3.4, 5.6), nrows=1, ncols=2, sharey=True)
ax0, ax1 = axes

ax_list = [ax0, ax0]
plt_list = [Hg, Hg_TOC]
labels = ["Hg (ppb)", "Hg/TOC (ppb/wt.%)"]
colors = ["black", "white"]
# remove the y-axis ticks and y-axis itself.
sns.despine(left=True, right=True, top=True, bottom=False)
plt.yticks([])

for i in range(len(ax_list)):
    sns.scatterplot(data=cha, x=plt_list[i], y=depth, ax=ax_list[i],
                    color=colors[i], legend=False, edgecolor='black',
                    size=20,
                    )
    ax_list[i].tick_params(labelsize=10)
    ax_list[i].set_xlabel(labels[i], fontsize=font_size, c="black", fontweight="bold")

ax0.set_xticks([0, 100,200])
plt.savefig(f'{save_path}WPND-corr.pdf')
# Out:
# meta NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped

# %%
fig, axes = plt.subplots(figsize=(3.6, 5.6), nrows=1, ncols = 2, sharey=True)
ax0, ax1 = axes

ax_list = [ax0, ax0, ax1]
plt_list = [Hg, Hg_TOC, D199]
labels = ["Hg (ppb)", "Hg/TOC (ppb/wt.%)", "$\Delta^{199}Hg\;(‰)$"]
colors=["black", "white", "black"]
# remove the y-axis ticks and y-axis itself.
sns.despine(left=True, right=True, top=True, bottom=False)
plt.yticks([])

for i in range(len(ax_list)):
    sns.scatterplot(data=cha, x=plt_list[i], y=depth, ax=ax_list[i],
                    color=colors[i], legend=False, edgecolor='black',
                    size=20,
                    )
    ax_list[i].tick_params(labelsize=font_size)
    ax_list[i].set_xlabel(labels[i], fontsize=font_size, c="black", fontweight="bold")
ax1.errorbar(xerr=err199, y=depth, x=D199, ecolor="black", color="black",
                  linestyle='none', elinewidth=0.7, capthick=0.5, mec='black')
ax1.axvline(x=-.05, linestyle='--', color='black', linewidth=1)
ax1.axvline(x=.05, linestyle='--', color='black', linewidth=1)
ax0.set_xticks([0, 100, 200])
ax1.set_xticks([-0.1, 0, 0.1,0.2])
plt.savefig(f'{save_path}Chaohu.pdf')
# Out:
# meta NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped

# %%
# import data into a pandas dataframe.
gur = pd.read_excel(data_path, sheet_name="Guryul")
gur.head(3)
# Out:
#         Locality sample  Lithology  depth       TOC  Hg_TOC    d202Hg  \
# 0  Guryul Ravine  GR113  limestone   47.7  0.035724     NaN -1.732299
# 1  Guryul Ravine  GR116  limestone   49.7  0.037863     NaN       NaN
# 2  Guryul Ravine  GR118  limestone   51.9  0.020141     NaN       NaN
#
#    d202_2se    D199Hg  D199_2se    D200Hg  D200_2se    D201Hg  D201_2se  \
# 0      0.02  0.017289      0.01  0.008907      0.03 -0.075686      0.01
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#     d13C   Hg
# 0  4.742  3.9
# 1  4.357  4.1
# 2  4.090  3.0

# %%
depth = gur.depth
D199 = gur.D199Hg
Hg = gur.Hg
Hg_TOC = gur.Hg_TOC
err199 = gur.D199_2se
d13C = gur.d13C

# %%
fig, axes = plt.subplots(figsize=(4, 6), nrows=1, ncols=3, sharey=True)
ax0, ax1, ax2 = axes

ax_list = [ax0, ax1, ax2]
plt_list = [Hg, D199, gur.D200Hg]
labels = ["Hg (ppb)", "$\Delta^{199}Hg\;(‰)$", "$\Delta^{200}Hg\;(‰)$"]
colors = ["black", "white", "black", "black"]
# remove the y-axis ticks and y-axis itself.
sns.despine(left=True, right=True, top=True, bottom=False)
plt.yticks([])

for i in range(len(ax_list)):
    sns.scatterplot(data=gur, x=plt_list[i], y=depth, ax=ax_list[i],
                    color='black', legend=False, edgecolor='black',
                    size=20,
                    )
    ax_list[i].tick_params(labelsize=font_size)
    ax_list[i].set_xlabel(labels[i], fontsize=font_size, c="black", fontweight="bold")
ax1.errorbar(xerr=err199, y=depth, x=D199, ecolor="black", color="black",
             linestyle='none', elinewidth=0.7, capthick=0.5, mec='black')
ax2.errorbar(xerr=gur.D200_2se, y=depth, x=gur.D200Hg, ecolor="black", color="black",
             linestyle='none', elinewidth=0.7, capthick=0.5, mec='black')
# ax0.set_xticks([0, 20, 40], c="black")
ax1.axvline(x=-.05, linestyle='--', color='black', linewidth=1)
ax1.axvline(x=.05, linestyle='--', color='black', linewidth=1)
ax2.axvline(x=.05, linestyle='--', color='black', linewidth=1)
ax2.axvline(x=-.05, linestyle='--', color='black', linewidth=1)
plt.savefig(f'{save_path}Guryul.pdf')
# Out:
# meta NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped

# %%
fig, axes = plt.subplots(figsize=(3.4, 6), nrows=1, ncols=2, sharey=True)
ax0, ax1 = axes

ax_list = [ax0, ax1]
plt_list = [Hg, d13C]
labels = ["Hg (ppb)", "$\delta^{13}C\;(‰\;VPDB)$"]
colors = ["black", "#848482"]
# remove the y-axis ticks and y-axis itself.
sns.despine(left=True, right=True, top=True, bottom=False)
plt.yticks([])

for i in range(len(ax_list)):
    sns.scatterplot(data=gur, x=plt_list[i], y=depth, ax=ax_list[i],
                    color=colors[i], legend=False, edgecolor='black',
                    size=20,
                    )
    ax_list[i].tick_params(labelsize=font_size)
    ax_list[i].set_xlabel(labels[i], fontsize=font_size, c="black", fontweight="bold")
# ax0.set_xticks([0, 20, 40], c="black")
plt.savefig(f'{save_path}Guryul-corr.pdf')
# Out:
# meta NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped

# %% [markdown]
# # Make box plots to compare Hg isotope data across different sections.

# %%
# import data into a pandas dataframe.
iso = pd.read_excel(data_path, sheet_name="iso_data")
iso.head(3)
# Out:
#   Locality            Author  sample    d202Hg    D199Hg    D200Hg    D201Hg
# 0   Chaohu  Wang et al. 2019  CH26-1 -1.196602  0.163477  0.011747  0.034643
# 1   Chaohu  Wang et al. 2019  CH27-5 -1.438952  0.091963  0.030875 -0.031976
# 2   Chaohu  Wang et al. 2019  CH31-2 -0.887090  0.111021  0.024028  0.013100

# %%
"""# Perform basic statistics on the data, grouped by localities.
iso_stats = iso.groupby('Locality').describe()
iso_stats.to_excel("../iso-lit-stats.xlsx", sheet_name="iso")
median_values = iso.groupby('Locality').median()

# export the stats to multiple sheets in a new excel file 
with pd.ExcelWriter("../stats.xlsx") as writer:
    iso_stats.to_excel(writer, sheet_name="descriptive-stats", index=True)
    median_values.to_excel(writer, sheet_name="median", index=True)

# #export the stats to multiple sheets in an existing excel file
with pd.ExcelWriter("../iso-lit-stats.xlsx", engine="openpyxl", mode='a') as writer:
    median_values.to_excel(writer, sheet_name="median", index=True)"""
# Out:
# '# Perform basic statistics on the data, grouped by localities.\niso_stats = iso.groupby(\'Locality\').describe()\niso_stats.to_excel("../iso-lit-stats.xlsx", sheet_name="iso")\nmedian_values = iso.groupby(\'Locality\').median()\n\n# export the stats to multiple sheets in a new excel file \nwith pd.ExcelWriter("../stats.xlsx") as writer:\n    iso_stats.to_excel(writer, sheet_name="descriptive-stats", index=True)\n    median_values.to_excel(writer, sheet_name="median", index=True)\n\n# #export the stats to multiple sheets in an existing excel file\nwith pd.ExcelWriter("../iso-lit-stats.xlsx", engine="openpyxl", mode=\'a\') as writer:\n    median_values.to_excel(writer, sheet_name="median", index=True)'

# %%
# Create figure
fig, (ax0, ax1, ax2) = plt.subplots(nrows=3, figsize=(6, 10), sharex=True)
plot_axes = [ax0,ax1,ax2]
plot_data =["d202Hg", "D199Hg", "D200Hg"]
colors = ["fuchsia", "salmon", "#33cb9c", "#289cc9"]
labels = ["$\delta^{202}Hg\;(‰)$", "$\Delta^{199}Hg\;(‰)$", "$\Delta^{200}Hg\;(‰)$"]
for i in range(len(plot_axes)):
    sns.boxplot(x='Locality', y=plot_data[i], data=iso, ax=plot_axes[i],
                medianprops={"color": "black"}, flierprops={"marker": "o"},
                width=0.5, palette=colors, showcaps=False)
    plot_axes[i].set_ylabel(labels[i], size=font_size, c="black", fontweight="bold")
    plot_axes[i].set_xlabel("Locality", size=font_size)
    plot_axes[i].tick_params(labelsize=font_size, color="black")

plt.savefig(f'{save_path}Hg-iso_boxplot.pdf')

# Create figure landscape mode
fig, (ax0, ax1, ax2) = plt.subplots(ncols=3, figsize=(11, 5), sharey=True)
plot_axes = [ax0, ax1, ax2]
plot_data = ["d202Hg", "D199Hg", "D200Hg"]

for i in range(len(plot_axes)):
    sns.boxplot(y='Locality', x=plot_data[i], data=iso, ax=plot_axes[i],
                medianprops={"color": "black"}, flierprops={"marker": "o"},
                width=0.5, palette=colors, showcaps=False)
    plot_axes[i].set_xlabel(labels[i], size=font_size, c="black", fontweight="bold")
    plot_axes[i].set_ylabel("Locality", size=font_size)
    plot_axes[i].tick_params(labelsize=font_size, color="black")

plt.savefig(f'{save_path}Hg-iso_boxplot-lscp.pdf')
# Out:
# meta NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped

# %%
wall = pd.read_excel(data_path, sheet_name='Hammer_2019')
wall.head(2)
# Out:
#    depth   TOC     Mo     Zr/Rb        Fe       V        Al    Hg   HI   OI  \
# 0  -18.0  1.14  27.50  3.948086  51739.95  263.82  74607.05  94.0  140   47
# 1  -12.0  0.76  19.37  3.748762  39308.24  227.36  78328.69  79.5  113  114
#
#     d13C      Hg_TOC
# 0 -33.69   82.456140
# 1 -33.77  104.605263

# %%
Hg = wall.Hg
Hg_TOC = wall.Hg_TOC
d13C = wall.d13C
depth = wall.depth

# %%
fig, axes = plt.subplots(figsize=(3.6, 5), nrows=1, ncols=2, sharey=True)
ax0, ax1 = axes
ax_list = [ax0, ax1]
plt_list = [Hg_TOC, d13C]
labels = ["Hg/TOC (ppb/wt.%)", "$\delta^{13}C\;(‰\;VPDB)$"]
colors = ["white", "#848482"]
# remove the y-axis ticks and y-axis itself.
sns.despine(left=True, right=True, top=True, bottom=False)
plt.yticks([])

def make_plot(data, f_size, f_name):
    for i in range(len(ax_list)):
        sns.scatterplot(data=data, x=plt_list[i], y=depth, ax=ax_list[i],
                        color=colors[i], legend=False, edgecolor='black',
                        size=20,
                        )
        ax_list[i].tick_params(labelsize=f_size)
        ax_list[i].set_xlabel(labels[i], fontsize=f_size, c="black", fontweight="bold")
    plt.savefig(f'{save_path}{f_name}.pdf')

make_plot(wall, font_size, 'wall-corr');
# Out:
# meta NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped

# %% [markdown]
# Jesmond section

# %%
jes = pd.read_excel(data_path, sheet_name='Jesmond')
jes.head(2)
# Out:
#              Author   Sample  Depth       Age        Hg       TOC     d13C  \
# 0  Shen et al. 2019  JE16-10   91.7  Spathian  1.422096  0.138371  1.48118
# 1               NaN   JE14-7   91.0  Spathian  6.850933  0.212109  1.76918
#
#       Hg_TOC
# 0        NaN
# 1  32.299147

# %%
depth=jes.Depth

# %%
fig, axes = plt.subplots(figsize=(3.6, 4.7), nrows=1, ncols=2, sharey=True)
ax0, ax1 = axes
ax_list = [ax0, ax0, ax1]
plt_list = [jes.Hg, jes.Hg_TOC, jes.d13C]
labels = ["Hg", "Hg/TOC (ppb/wt.%)", "$\delta^{13}C\;(‰\;VPDB)$"]
colors = ["black", "white", "#848482"]
# remove the y-axis ticks and y-axis itself.
sns.despine(left=True, right=True, top=True, bottom=False)
plt.yticks([])

make_plot(jes, font_size, 'jes-corr');
# Out:
# meta NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped

# %% [markdown]
# Smith Creek data

# %%
sc = pd.read_excel(data_path, sheet_name='Smith_Creek')
depth=sc.depth
sc.head(2)
# Out:
#          sample       Author       Age  Hg (ug/g)  Hg  d13C   TOC  Hg_TOC  \
# 0  GQA09-25-123  Grasby 2013  Smithian      0.013  13 -26.2  0.10     NaN
# 1  GQA09-25-124  Grasby 2013  Smithian      0.005   5 -23.9  0.11     NaN
#
#    depth
# 0  382.0
# 1  385.0

# %%
fig, axes = plt.subplots(figsize=(3.2, 5.2), nrows=1, ncols=2, sharey=True)
ax0, ax1 = axes
ax_list = [ax0, ax0, ax1]
plt_list = [sc.Hg_TOC, sc.Hg, sc.d13C]
labels = ["Hg/TOC (ppb/wt.%)","Hg/TOC (ppb/wt.%)", "$\delta^{13}C\;(‰\;VPDB)$"]
colors = ["white", "black", "#848482"]
# remove the y-axis ticks and y-axis itself.
sns.despine(left=True, right=True, top=True, bottom=False)
plt.yticks([])

make_plot(sc, font_size, 'sc-corr');
ax0.axhline(y=470, linestyle='--', color='black')
ax0.axhline(y=550, linestyle='--', color='black')
# Out:
# meta NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped

# %% [markdown]
# Festningen Section

# %%
fest = pd.read_excel(data_path, sheet_name='festningen')
depth=fest.Depth
fest.head(2)
# Out:
#                Author  Depth           Age  Hg   TOC  Hg_TOC  Corg
# 0  Grasby et al. 2016  182.3  mid-Smithian   4  0.04     NaN -26.5
# 1                 NaN  196.8  mid-Smithian   7  0.06     NaN -24.7

# %%
fig, axes = plt.subplots(figsize=(3.6, 4.9), nrows=1, ncols=2, sharey=True)
ax0, ax1 = axes
ax_list = [ax0, ax0, ax1]
plt_list = [fest.Hg, fest.Hg_TOC, fest.Corg]
labels = ["Hg", "Hg/TOC (ppb/wt.%)", "$\delta^{13}C\;(‰\;VPDB)$"]
colors = ["black", "white", "#848482"]
# remove the y-axis ticks and y-axis itself.
sns.despine(left=True, right=True, top=True, bottom=False)
plt.yticks([])

make_plot(fest, font_size, 'fest-corr')
# Out:
# meta NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped

# %% [markdown]
# Zuodeng section

# %%
zd = pd.read_excel(data_path, sheet_name='Zuodeng')
depth = zd.Depth
zd.head(2)
# Out:
#              Author  Depth       Age  Hg     TOC  Hg_TOC  d13C
# 0  Shen et al. 2019   8690  Spathian NaN  0.0763     NaN   NaN
# 1               NaN   8660  Spathian NaN  0.0800     NaN   NaN

# %%
fig, axes = plt.subplots(figsize=(3.4, 5.5), nrows=1, ncols=2, sharey=True)
ax0, ax1 = axes
ax_list = [ax0, ax0, ax1]
plt_list = [zd.Hg, zd.Hg_TOC, zd.d13C]
labels = ["Hg", "Hg (ppb)", "$\delta^{13}C\;(‰\;VPDB)$"]
colors = ["black", "white", "#848482"]
# remove the y-axis ticks and y-axis itself.
sns.despine(left=True, right=True, top=True, bottom=False)
plt.yticks([])

make_plot(zd, font_size, 'zd-corr')
# Out:
# meta NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped

# %%
npds = pd.read_excel(data_path, sheet_name='NPDS')
depth = npds.Depth
npds.head(2)
npds['Hg_TOC'].count()
# Out:
# 34

# %%
fig, axes = plt.subplots(figsize=(3.4, 5.9), nrows=1, ncols=2, sharey=True)
ax0, ax1 = axes
ax_list = [ax0, ax0, ax1]
plt_list = [npds.Hg_TOC, npds.Hg, npds.d13C]
labels = ["Hg", "Hg/TOC", "$\delta^{13}C\;(‰\;VPDB)$"]
colors = ["white", "black", "#848482"]
# remove the y-axis ticks and y-axis itself.
sns.despine(left=True, right=True, top=True, bottom=False)
plt.yticks([])

make_plot(npds, font_size, 'npds-corr')
# Out:
# meta NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped

# %% [markdown]
# Mud section

# %%
mud = pd.read_excel(data_path, sheet_name='Mud')
depth = mud.Depth
mud.head(2)
# Out:
#              Author      Depth       Age         Hg     TOC  Hg_TOC      d13C
# 0  Shen et al. 2019  16.018438  Spathian  38.489557  0.1589     NaN  1.800578
# 1               NaN  15.846562  Spathian  77.894549  0.1720     NaN  2.061400

# %%
fig, axes = plt.subplots(figsize=(3.4, 4.1), nrows=1, ncols=2, sharey=True)
ax0, ax1 = axes
ax_list = [ax0, ax1]
plt_list = [mud.Hg, mud.d13C]
labels = ["Hg (ppb)", "$\delta^{13}C\;(‰\;VPDB)$"]
colors = ["black", "#848482"]
# remove the y-axis ticks and y-axis itself.
sns.despine(left=True, right=True, top=True, bottom=False)
plt.yticks([])

make_plot(mud, 12, 'mud-corr')
# Out:
# meta NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped
